# %%
import pandas as pd

df = pd.read_csv("scottish_hills.csv")
height_df = df[df['Height'] == 997.0]
height_df.head()
# Out:
#             Hill Name  Height   Latitude  Longitude    Osgrid
# 1       A' Chailleach   997.0  57.693800  -5.128715  NH136714
# 162  Glas Bheinn Mhor   997.0  56.542389  -5.005249  NN153429

# %%
import pandas as pd

df = pd.read_csv("scottish_hills.csv")
latitude_df = df['Latitude']
latitude_df.head(20)
latitude_df.plot()
